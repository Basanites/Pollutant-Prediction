# %% [markdown]
# ##Importing all csv files using a MultiIndex structure
#
# Samplingpoint -> Pollutant -> StartTime
#
# Rows containing Bulk in the Samplingpoint name are dropped, because they are only monthly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
# %matplotlib inline

package_dir = os.getcwd()

print(package_dir)

df = pd.DataFrame()

print('Loading CSVs\n')
for file in glob.glob('res/*.csv'):
    read = pd.read_csv(file,
                 encoding="utf-16", parse_dates=[13, 14],
                 infer_datetime_format=True,
                 index_col=[4, 8, 13])
    df = pd.concat([df, read])
print('\nFinished Loading')
print('Sorting')
df = df.sort_index()
print('Finished sorting')
# Out:
# /home/sebastian/Programming/Bachelorthesis
# Loading CSVs
#
#
# Finished Loading
# Sorting
# Finished sorting

# %%
print(df.dtypes)
print(df.head())
# Out:
# Countrycode                  object
# Namespace                    object
# AirQualityNetwork            object
# AirQualityStation            object
# SamplingPoint                object
# SamplingProcess              object
# Sample                       object
# AirPollutantCode             object
# AveragingTime                object
# Concentration               float64
# UnitOfMeasurement            object
# DatetimeEnd          datetime64[ns]
# Validity                      int64
# Verification                  int64
# dtype: object
#                                                           Countrycode  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00          DE
#                                       2013-01-06 23:00:00          DE
#                                       2013-01-12 23:00:00          DE
#                                       2013-01-18 23:00:00          DE
#                                       2013-01-24 23:00:00          DE
#
#                                                                                                    Namespace  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00  http://gdi.uba.de/arcgis/rest/services/inspire...
#                                       2013-01-06 23:00:00  http://gdi.uba.de/arcgis/rest/services/inspire...
#                                       2013-01-12 23:00:00  http://gdi.uba.de/arcgis/rest/services/inspire...
#                                       2013-01-18 23:00:00  http://gdi.uba.de/arcgis/rest/services/inspire...
#                                       2013-01-24 23:00:00  http://gdi.uba.de/arcgis/rest/services/inspire...
#
#                                                           AirQualityNetwork  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00         NET.DE_SN
#                                       2013-01-06 23:00:00         NET.DE_SN
#                                       2013-01-12 23:00:00         NET.DE_SN
#                                       2013-01-18 23:00:00         NET.DE_SN
#                                       2013-01-24 23:00:00         NET.DE_SN
#
#                                                           AirQualityStation  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00    STA.DE_DESN025
#                                       2013-01-06 23:00:00    STA.DE_DESN025
#                                       2013-01-12 23:00:00    STA.DE_DESN025
#                                       2013-01-18 23:00:00    STA.DE_DESN025
#                                       2013-01-24 23:00:00    STA.DE_DESN025
#
#                                                                                SamplingPoint  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00  SPO.DE_DESN025_PM10_As_dataGroup3
#                                       2013-01-06 23:00:00  SPO.DE_DESN025_PM10_As_dataGroup3
#                                       2013-01-12 23:00:00  SPO.DE_DESN025_PM10_As_dataGroup3
#                                       2013-01-18 23:00:00  SPO.DE_DESN025_PM10_As_dataGroup3
#                                       2013-01-24 23:00:00  SPO.DE_DESN025_PM10_As_dataGroup3
#
#                                                                                              SamplingProcess  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00  SPP.DE_DESN025_PM10_As_active_HVSauto30_GF_AAS...
#                                       2013-01-06 23:00:00  SPP.DE_DESN025_PM10_As_active_HVSauto30_GF_AAS...
#                                       2013-01-12 23:00:00  SPP.DE_DESN025_PM10_As_active_HVSauto30_GF_AAS...
#                                       2013-01-18 23:00:00  SPP.DE_DESN025_PM10_As_active_HVSauto30_GF_AAS...
#                                       2013-01-24 23:00:00  SPP.DE_DESN025_PM10_As_active_HVSauto30_GF_AAS...
#
#                                                                      Sample  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00  SAM.DE_DESN025_2
#                                       2013-01-06 23:00:00  SAM.DE_DESN025_2
#                                       2013-01-12 23:00:00  SAM.DE_DESN025_2
#                                       2013-01-18 23:00:00  SAM.DE_DESN025_2
#                                       2013-01-24 23:00:00  SAM.DE_DESN025_2
#
#                                                                                             AirPollutantCode  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
#                                       2013-01-06 23:00:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
#                                       2013-01-12 23:00:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
#                                       2013-01-18 23:00:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
#                                       2013-01-24 23:00:00  http://dd.eionet.europa.eu/vocabulary/aq/pollu...
#
#                                                           AveragingTime  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00           day
#                                       2013-01-06 23:00:00           day
#                                       2013-01-12 23:00:00           day
#                                       2013-01-18 23:00:00           day
#                                       2013-01-24 23:00:00           day
#
#                                                            Concentration  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00          2.924
#                                       2013-01-06 23:00:00          0.836
#                                       2013-01-12 23:00:00          1.384
#                                       2013-01-18 23:00:00          8.042
#                                       2013-01-24 23:00:00          2.881
#
#                                                           UnitOfMeasurement  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00             ng/m3
#                                       2013-01-06 23:00:00             ng/m3
#                                       2013-01-12 23:00:00             ng/m3
#                                       2013-01-18 23:00:00             ng/m3
#                                       2013-01-24 23:00:00             ng/m3
#
#                                                                   DatetimeEnd  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00 2013-01-01 23:00:00
#                                       2013-01-06 23:00:00 2013-01-07 23:00:00
#                                       2013-01-12 23:00:00 2013-01-13 23:00:00
#                                       2013-01-18 23:00:00 2013-01-19 23:00:00
#                                       2013-01-24 23:00:00 2013-01-25 23:00:00
#
#                                                            Validity  \
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00         1
#                                       2013-01-06 23:00:00         1
#                                       2013-01-12 23:00:00         1
#                                       2013-01-18 23:00:00         1
#                                       2013-01-24 23:00:00         1
#
#                                                            Verification
# AirQualityStationEoICode AirPollutant DatetimeBegin
# DESN025                  As in PM10   2012-12-31 23:00:00             1
#                                       2013-01-06 23:00:00             1
#                                       2013-01-12 23:00:00             1
#                                       2013-01-18 23:00:00             1
#                                       2013-01-24 23:00:00             1

# %% [markdown]
# Multiindex can be navigated using the loc method.
#
# Row selection is done via the [] operator using counting slices or datetime parsed from strings

# %%
df.loc['DESN025', 'C6H6']['2014-01':'2014-02'].plot(y='Concentration', figsize=(14,8))

# %%
#print(df.loc['DESN025'].groupby(['AirPollutant']).count()['AirPollutantCode'])

# %%
for eoi, new_df in df.groupby(level=0):
    print(new_df.groupby(['AirPollutant']).count()['AirPollutantCode'], '\n')
